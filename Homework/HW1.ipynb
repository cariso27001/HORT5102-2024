# %% [markdown]
# # Homework 1

# %% [markdown]
# The following data was digitized from a research article documenting the time-series pattern of plant height. The original article compares the growth yield, plant quality, and nutritional status of basil grown under two different soilless cultivation systems. Please observe the following data and figure in detail and try to answer the provided questions at the end of this notebook.

# %% [markdown]
# <div class="alert alert-warning">
# If equations or tables are not displayed properly, please go to the top menu and select View - Activate Command Palette, then search for and execute the "Trust Notebook" command.
# </div>

# %%
using Cropbox
using DataFrames

Cropbox.Interact.WebIO.setup(:ijulia)
# Out:
# WebIO._IJuliaInit()
# WebIO._IJuliaInit()

# %%
BasilHeight = DataFrame((
    Week=[1:1:15;],
    Hydroponics=[9.85,12.53,14.91,19.65,27.14,31.15,40.30,48.46,51.54,56.43,63.18,71.62,73.48,74.76,78.63],
    Aquaponics=[10.91,20.10,27.60,35.53,44.35,52.28,62.70,71.37,76.22,78.18,83.78,85.09,86.74,88.20,89.90],
))
# Out:
# 15×3 DataFrame
#  Row │ Week   Hydroponics  Aquaponics
#      │ Int64  Float64      Float64
# ─────┼────────────────────────────────
#    1 │     1         9.85       10.91
#    2 │     2        12.53       20.1
#    3 │     3        14.91       27.6
#    4 │     4        19.65       35.53
#    5 │     5        27.14       44.35
#    6 │     6        31.15       52.28
#    7 │     7        40.3        62.7
#    8 │     8        48.46       71.37
#    9 │     9        51.54       76.22
#   10 │    10        56.43       78.18
#   11 │    11        63.18       83.78
#   12 │    12        71.62       85.09
#   13 │    13        73.48       86.74
#   14 │    14        74.76       88.2
#   15 │    15        78.63       89.9

# %%
BasilHeightPlot = plot(BasilHeight, :Week, [:Hydroponics,:Aquaponics]; ylim=(0,100), ylab = "Plant height (cm)")
# Out:
# "<Cropbox.Plot{Gadfly.Plot}>"

# %% [markdown]
# ### Homework Questions:
# 1. Please use the growth functions you learned today to fit the growth pattern (plant height versus week) of the basil grown under two soilless cultivation systems. Justify the reasons why you chose these models. </br> *Note: you can use different functions separately on the two cultivation systems, but you still need to explain why you chose each model.* </br></br>
#
# 2. Please conduct a calibration process on the two growing scenarios using the built-in `calibrate` function provided by the Cropbox framework, and replot the figure with the new parameter configuration. Do you think the model performs better after the calibration process? Why or why not? </br></br>
#
# **Please upload your answer to NTU Cool system. Accepted format: .docx .pdf .ipynb .jl .zip .tar.gz**

# %% [markdown]
# ### References:
# Subhrajit Saha, Amber Monroe, Martin R. Day,
# Growth, yield, plant quality and nutrition of basil (*Ocimum basilicum* L.) under soilless agricultural systems,
# Annals of Agricultural Sciences,
# Volume 61, Issue 2,
# 2016,
# Pages 181-186,
# ISSN 0570-1783,
# https://doi.org/10.1016/j.aoas.2016.10.001.
